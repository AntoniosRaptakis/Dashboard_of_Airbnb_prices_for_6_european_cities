# %% [markdown]
# This notebook reads the dataset, which the 'merge_and_clean_the dataset.ipynb' has created and then creates a new dataset with the mean values per room type option per neighbourhood and overall mean per neighbourhood.
#
# The geojson file has all listed neighbourhoods, however the dataset has only data for some of them. Thus, it creates a new geojson file with a limited number neighbourhoods and the geometries.

# %% [markdown]
# #### Import the libraries

# %%
import numpy as np
import pandas as pd
import geopandas
import folium
from folium.features import DivIcon
# Out:
# /Users/antonis1991/opt/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# <ipython-input-1-16da542a7bbb>:3: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas

# %% [markdown]
# #### Read the data

# %% [markdown]
# Read the csv file which have been created by the notebook 'merge_and_clean_the dataset.ipynb'.

# %%
data=pd.read_csv('airbnb_prices_in_6_european_cities.csv')
data
# Out:
#        Unnamed: 0   Price     Room type  Person capacity  Longitude  Latitude  \
# 0               0  194.03  Private room                2    4.90569  52.41772
# 1               1  344.25  Private room                4    4.90005  52.37432
# 2               2  264.10  Private room                2    4.97512  52.36103
# 3               3  433.53  Private room                4    4.89417  52.37663
# 4               4  485.55  Private room                2    4.90051  52.37508
# ...           ...     ...           ...              ...        ...       ...
# 17784       17784  310.45  Private room                2   -0.21207  51.48667
# 17785       17785  265.06   Entire home                4   -0.05459  51.52018
# 17786       17786  142.29  Private room                2   -0.12056  51.42875
# 17787       17787  372.30  Private room                2   -0.12810  51.44023
# 17788       17788  573.16   Entire home                6   -0.08009  51.56266
#
#             City             Neighbourhood
# 0      Amsterdam                Noord-West
# 1      Amsterdam              Centrum-West
# 2      Amsterdam  IJburg - Zeeburgereiland
# 3      Amsterdam              Centrum-West
# 4      Amsterdam              Centrum-West
# ...          ...                       ...
# 17784     London    Hammersmith and Fulham
# 17785     London             Tower Hamlets
# 17786     London                   Lambeth
# 17787     London                   Lambeth
# 17788     London                   Hackney
#
# [17789 rows x 8 columns]

# %% [markdown]
# #### Delete the column 'Unnamed: 0'

# %%
data = data.drop('Unnamed: 0', axis=1)
data.head()
# Out:
#     Price     Room type  Person capacity  Longitude  Latitude       City  \
# 0  194.03  Private room                2    4.90569  52.41772  Amsterdam
# 1  344.25  Private room                4    4.90005  52.37432  Amsterdam
# 2  264.10  Private room                2    4.97512  52.36103  Amsterdam
# 3  433.53  Private room                4    4.89417  52.37663  Amsterdam
# 4  485.55  Private room                2    4.90051  52.37508  Amsterdam
#
#               Neighbourhood
# 0                Noord-West
# 1              Centrum-West
# 2  IJburg - Zeeburgereiland
# 3              Centrum-West
# 4              Centrum-West

# %% [markdown]
# # Read the geojson files

# %% [markdown]
# I read the geojson files and I change name of the column neighbourhood -> Neighbourhood

# %%
nbh_geo_amsterdam = geopandas.read_file('Amsterdam_neighbourhoods/neighbourhoods.geojson', driver='GeoJSON')
nbh_geo_amsterdam = nbh_geo_amsterdam.rename({'neighbourhood': 'Neighbourhood'}, axis=1)

nbh_geo_lisbon = geopandas.read_file('Lisbon_neighbourhoods/neighbourhoods.geojson', driver='GeoJSON')
nbh_geo_lisbon = nbh_geo_lisbon.rename({'neighbourhood': 'Neighbourhood'}, axis=1)

nbh_geo_london = geopandas.read_file('London_neighbourhoods/neighbourhoods.geojson', driver='GeoJSON')
nbh_geo_london = nbh_geo_london.rename({'neighbourhood': 'Neighbourhood'}, axis=1)

nbh_geo_paris = geopandas.read_file('Paris_neighbourhoods/neighbourhoods.geojson', driver='GeoJSON')
nbh_geo_paris = nbh_geo_paris.rename({'neighbourhood': 'Neighbourhood'}, axis=1)

nbh_geo_rome = geopandas.read_file('Rome_neighbourhoods/neighbourhoods.geojson', driver='GeoJSON')
nbh_geo_rome = nbh_geo_rome.rename({'neighbourhood': 'Neighbourhood'}, axis=1)

nbh_geo_vienna = geopandas.read_file('Vienna_neighbourhoods/neighbourhoods.geojson', driver='GeoJSON')
nbh_geo_vienna = nbh_geo_vienna.rename({'neighbourhood': 'Neighbourhood'}, axis=1)
# Make the change that at some listings 
for i in range(nbh_geo_vienna.shape[0]):
    if nbh_geo_vienna.iloc[i,0]=='Rudolfsheim-Fnfhaus':
        nbh_geo_vienna.iloc[i,0]='Rudolfsheim-Fünfhaus'
    elif nbh_geo_vienna.iloc[i,0]=='Landstra§e':
        nbh_geo_vienna.iloc[i,0]='Landstrasse'
    elif nbh_geo_vienna.iloc[i,0]=='Whring':
        nbh_geo_vienna.iloc[i,0]='Währing'
    elif nbh_geo_vienna.iloc[i,0]=='Dbling':
        nbh_geo_vienna.iloc[i,0]='Döbling'


nbh_geo_files = {'Amsterdam': nbh_geo_amsterdam,
                 'Lisbon': nbh_geo_lisbon,
                 'London': nbh_geo_london,
                 'Paris': nbh_geo_paris,
                 'Rome': nbh_geo_rome,
                 'Vienna': nbh_geo_vienna}

# %%
nbh_geo_files['Vienna']
# Out:
#            Neighbourhood neighbourhood_group  \
# 0           Leopoldstadt                None
# 1            Landstrasse                None
# 2           Innere Stadt                None
# 3            Brigittenau                None
# 4            Floridsdorf                None
# 5             Donaustadt                None
# 6                Liesing                None
# 7             Alsergrund                None
# 8                Penzing                None
# 9              Mariahilf                None
# 10                Neubau                None
# 11             Simmering                None
# 12             Favoriten                None
# 13              Hietzing                None
# 14              Meidling                None
# 15  Rudolfsheim-Fünfhaus                None
# 16            Margareten                None
# 17            Josefstadt                None
# 18                Wieden                None
# 19               Hernals                None
# 20             Ottakring                None
# 21               Döbling                None
# 22               Währing                None
#
#                                              geometry
# 0   MULTIPOLYGON (((16.38484 48.22616, 16.38495 48...
# 1   MULTIPOLYGON (((16.38681 48.21271, 16.38683 48...
# 2   MULTIPOLYGON (((16.36497 48.21590, 16.36498 48...
# 3   MULTIPOLYGON (((16.38595 48.24764, 16.38611 48...
# 4   MULTIPOLYGON (((16.37817 48.28858, 16.37819 48...
# 5   MULTIPOLYGON (((16.48378 48.17615, 16.48358 48...
# 6   MULTIPOLYGON (((16.33924 48.15405, 16.33948 48...
# 7   MULTIPOLYGON (((16.34255 48.21837, 16.34259 48...
# 8   MULTIPOLYGON (((16.27508 48.21508, 16.27512 48...
# 9   MULTIPOLYGON (((16.34200 48.19634, 16.34424 48...
# 10  MULTIPOLYGON (((16.35825 48.20511, 16.35830 48...
# 11  MULTIPOLYGON (((16.40375 48.18527, 16.40375 48...
# 12  MULTIPOLYGON (((16.37081 48.14898, 16.37042 48...
# 13  MULTIPOLYGON (((16.27916 48.16268, 16.27693 48...
# 14  MULTIPOLYGON (((16.33729 48.17093, 16.33729 48...
# 15  MULTIPOLYGON (((16.32531 48.20531, 16.32534 48...
# 16  MULTIPOLYGON (((16.36476 48.18798, 16.36545 48...
# 17  MULTIPOLYGON (((16.33903 48.21106, 16.33904 48...
# 18  MULTIPOLYGON (((16.37505 48.19815, 16.37505 48...
# 19  MULTIPOLYGON (((16.31112 48.22277, 16.31097 48...
# 20  MULTIPOLYGON (((16.32645 48.20513, 16.32534 48...
# 21  MULTIPOLYGON (((16.30836 48.27243, 16.30908 48...
# 22  MULTIPOLYGON (((16.31557 48.23254, 16.31554 48...

# %% [markdown]
# The function below is calculating the mean values per room type option and per neighbourhood and the overall mean per neighbourhood. It takes the data for a specific city and returns a dataset with specific columns ,including the calculated means per neighbourhood, and the new geojson files.

# %%
def find_the_means(df,city,geo_file):
    
    # This part calculates the mean values per Neighbourhood for the option 'Private room'
    check_priv_room = pd.DataFrame(data[(data['Room type']=="Private room") & 
                                  (data.City==city)].groupby("Neighbourhood").Price.mean()).reset_index()
    check_priv_room = check_priv_room.merge(geo_file, on="Neighbourhood")
    check_priv_room = check_priv_room.drop(["neighbourhood_group"], axis=1)
    check_priv_room = check_priv_room.rename(columns={'Price':'Mean Priv. room',
                                                      'geometry':'geometry_priv_room'})
    
    
    # This part calculates the mean values per Neighbourhood for the option 'Entire home'
    check_ent_home = pd.DataFrame(data[(data['Room type']=="Entire home") & 
                                       (data.City==city)].groupby("Neighbourhood").Price.mean()).reset_index()
    check_ent_home = check_ent_home.merge(geo_file, on="Neighbourhood")
    check_ent_home = check_ent_home.drop(["neighbourhood_group"], axis=1)
    check_ent_home = check_ent_home.rename(columns={'Price':'Mean Ent. home',
                                                    'geometry':'geometry_ent_home'})

    
    # This part calculates the mean values per Neighbourhood (irregardless the Room type)
    overall_mean_per_neighbourhood = pd.DataFrame(data[data.City==city].groupby("Neighbourhood").Price.mean()).reset_index()
    overall_mean_per_neighbourhood = overall_mean_per_neighbourhood.rename(columns={'Price':'Overall Mean'})


    # I merge (join) the datasets. Nan values will be created
    if len(check_priv_room.geometry_priv_room.values)>=len(check_ent_home.geometry_ent_home.values):
        merged = check_ent_home.merge(check_priv_room, how='right', on='Neighbourhood')
        merged = merged.drop(['geometry_ent_home'], axis=1)
        merged = merged.rename(columns={'geometry_priv_room':'geometry'})
    else:
        merged = check_ent_home.merge(check_priv_room, how='left', on='Neighbourhood')
        merged = merged.drop('geometry_priv_room', axis=1)
        merged = merged.rename(columns={'geometry_ent_home':'geometry'})
    
    
    # The final merged dataset;
    # I add a column for the city;
    # I recreate the dataset with the columns being in a specific row
    final_merged = overall_mean_per_neighbourhood.merge(merged,on="Neighbourhood")
    column_city = [city]*final_merged.shape[0]
    final_merged["City"] = column_city
    final_merged = final_merged[['City', 'Neighbourhood', 'Overall Mean','Mean Ent. home', 
                                 'Mean Priv. room', 'geometry']]
    
    
    # This part calculates the centroid point per Neighbourhood and I add it in the dataset
    geo1 = geo_file.copy()
    geo1['Centroid']=geo1.geometry.centroid.values
    geo1 = geo1.drop(['neighbourhood_group','geometry'], axis=1)
    final_merged = final_merged.merge(geo1,on="Neighbourhood")
    
    
    # This part checks which are the neighbourhoods that have been included in the final dataset
    # and removes from the copied version of geo_file those who does not exist. I return this one
    # as well!
    geo_new = final_merged[["Neighbourhood",'geometry']]
    geo_new = geopandas.GeoDataFrame(geo_new, geometry='geometry')
    
    
    return final_merged, geo_new

# %% [markdown]
# #### I use the function above for each city and append the results on a dataset

# %%
means_summary, new_nbh_geo_file_amsterdam = find_the_means(data,'Amsterdam',nbh_geo_files['Amsterdam'])

new_nbh_geo_file = {'Amsterdam':new_nbh_geo_file_amsterdam}

for city in data.City.unique()[1:]:
    
    mitsos, new_geo_file = find_the_means(data,city,nbh_geo_files[city])
    
    means_summary = means_summary.append(mitsos, ignore_index=True)
    
    new_nbh_geo_file[city] = new_geo_file
# Out:
# <ipython-input-6-23aaf043f151>:49: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geo1['Centroid']=geo1.geometry.centroid.values
# <ipython-input-6-23aaf043f151>:49: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geo1['Centroid']=geo1.geometry.centroid.values
# <ipython-input-6-23aaf043f151>:49: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geo1['Centroid']=geo1.geometry.centroid.values
# <ipython-input-6-23aaf043f151>:49: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geo1['Centroid']=geo1.geometry.centroid.values
# <ipython-input-6-23aaf043f151>:49: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geo1['Centroid']=geo1.geometry.centroid.values
# <ipython-input-6-23aaf043f151>:49: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   geo1['Centroid']=geo1.geometry.centroid.values

# %%
means_summary.City.value_counts()#[means_summary.]
# Out:
# Vienna       23
# Lisbon       23
# Amsterdam    22
# Paris        20
# Rome         14
# London       13
# Name: City, dtype: int64

# %% [markdown]
# I define a function for the visualization of the results, just only to check the out the visualization

# %%
def visualization_with_folium(df, x, center, geo_city):
    
    map = folium.Map(location=center,
                     tiles="cartodbpositron",zoom_start=12.5) 
    folium.Marker(location=center,
                  icon = folium.Icon(color='black')).add_to(map)

    folium.Choropleth(geo_data=geo_city,
                      name="choropleth",
                      data=df[x],
                      columns=["Neighbourhood", x],
                      key_on="feature.id",
                      fill_color="RdYlGn",
                      fill_opacity=0.6,
                      line_opacity=0.6,
                      legend_name="Mean of Total Prices",).add_to(map)

    folium.LayerControl().add_to(map)
    
    for i,location in enumerate(df.Centroid.values):
        loc=[location.y,location.x] #+0.004
        folium.map.Marker(loc, icon=DivIcon(icon_size=(20,20),
                                            icon_anchor=(0,0),
                                            html='<div style="font-size: 10pt">%s</div>' %df['Neighbourhood'][i])).add_to(map)


    return map

# %%
#[Latitude,Longitude]
capitals_lat_lng = {'Amsterdam': [52.377956,4.897070],
                    'Lisbon': [38.736946, -9.142685],
                    'London': [51.509865, -0.118092],
                    'Paris': [48.864716, 2.349014],
                    'Rome': [41.902782, 12.496366],
                    'Vienna': [48.210033, 16.363449]}

# %% [markdown]
# ### Check Lisbon

# %%
visualization_with_folium(means_summary, 'Overall Mean',
                          capitals_lat_lng['Lisbon'],
                          new_nbh_geo_file['Lisbon'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_541c160c6a32547dc71fdf1226b799fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_541c160c6a32547dc71fdf1226b799fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_541c160c6a32547dc71fdf1226b799fb = L.map(
#                 &quot;map_541c160c6a32547dc71fdf1226b799fb&quot;,
#                 {
#                     center: [38.736946, -9.142685],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_387e7af7338e5a67c94ddfbc3a51c201 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_541c160c6a32547dc71fdf1226b799fb);
#
#
#             var marker_391f20706277a1ff2a11e654710e306c = L.marker(
#                 [38.736946, -9.142685],
#                 {}
#             ).addTo(map_541c160c6a32547dc71fdf1226b799fb);
#
#
#             var icon_c59852eb7936e1049f5e32e38c8b9290 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_391f20706277a1ff2a11e654710e306c.setIcon(icon_c59852eb7936e1049f5e32e38c8b9290);
#
#
#             var choropleth_7f7f827051f82282d5c25ead25ffa2c4 = L.featureGroup(
#                 {}
#             ).addTo(map_541c160c6a32547dc71fdf1226b799fb);
#
#
#         function geo_json_cca2ebdf73f1dfa690d6b91dc7456b3e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;6&quot;: case &quot;12&quot;: case &quot;15&quot;: case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#91cf60&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;4&quot;: case &quot;5&quot;: case &quot;8&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1a9850&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;7&quot;: case &quot;10&quot;: case &quot;14&quot;: case &quot;17&quot;: case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9ef8b&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee08b&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_cca2ebdf73f1dfa690d6b91dc7456b3e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_cca2ebdf73f1dfa690d6b91dc7456b3e = L.geoJson(null, {
#                 onEachFeature: geo_json_cca2ebdf73f1dfa690d6b91dc7456b3e_onEachFeature,
#
#                 style: geo_json_cca2ebdf73f1dfa690d6b91dc7456b3e_styler,
#         });
#
#         function geo_json_cca2ebdf73f1dfa690d6b91dc7456b3e_add (data) {
#             geo_json_cca2ebdf73f1dfa690d6b91dc7456b3e
#                 .addData(data)
#                 .addTo(choropleth_7f7f827051f82282d5c25ead25ffa2c4);
#         }
#             geo_json_cca2ebdf73f1dfa690d6b91dc7456b3e_add({&quot;bbox&quot;: [-9.237916, 38.680028, -9.086309, 38.796755], &quot;features&quot;: [{&quot;bbox&quot;: [-9.210058, 38.700416, -9.186106, 38.724765], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-9.193357, 38.700578], [-9.19364, 38.700425], [-9.193656, 38.700416], [-9.193935, 38.700706], [-9.194264, 38.701098], [-9.194303, 38.701087], [-9.194649, 38.700992], [-9.196239, 38.700553], [-9.196724, 38.701578], [-9.196876, 38.701869], [-9.19825, 38.701951], [-9.198411, 38.701967], [-9.198485, 38.701975], [-9.198654, 38.702035], [-9.199119, 38.702199], [-9.199581, 38.702352], [-9.199587, 38.702287], [-9.199762, 38.701128], [-9.199777, 38.70103], [-9.199804, 38.700856], [-9.199946, 38.700887], [-9.200437, 38.700993], [-9.200763

# %%
visualization_with_folium(means_summary, 'Mean Priv. room',
                          capitals_lat_lng['Lisbon'],
                          new_nbh_geo_file['Lisbon'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc5010b0b17a4ddb496ef3b3471ac51c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc5010b0b17a4ddb496ef3b3471ac51c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc5010b0b17a4ddb496ef3b3471ac51c = L.map(
#                 &quot;map_cc5010b0b17a4ddb496ef3b3471ac51c&quot;,
#                 {
#                     center: [38.736946, -9.142685],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f8265298194da1ab6cccb40691f1631 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cc5010b0b17a4ddb496ef3b3471ac51c);
#
#
#             var marker_01b517c111e4d14f1fc1b748b26cb1cc = L.marker(
#                 [38.736946, -9.142685],
#                 {}
#             ).addTo(map_cc5010b0b17a4ddb496ef3b3471ac51c);
#
#
#             var icon_b2a347eb9bfdb72fb71342946cbf8556 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_01b517c111e4d14f1fc1b748b26cb1cc.setIcon(icon_b2a347eb9bfdb72fb71342946cbf8556);
#
#
#             var choropleth_18d7dcbb32443d82bf510f49717b020f = L.featureGroup(
#                 {}
#             ).addTo(map_cc5010b0b17a4ddb496ef3b3471ac51c);
#
#
#         function geo_json_ade4b0c32f80ac0a5f507561177049ed_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;15&quot;: case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d73027&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;4&quot;: case &quot;5&quot;: case &quot;19&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee08b&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ade4b0c32f80ac0a5f507561177049ed_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ade4b0c32f80ac0a5f507561177049ed = L.geoJson(null, {
#                 onEachFeature: geo_json_ade4b0c32f80ac0a5f507561177049ed_onEachFeature,
#
#                 style: geo_json_ade4b0c32f80ac0a5f507561177049ed_styler,
#         });
#
#         function geo_json_ade4b0c32f80ac0a5f507561177049ed_add (data) {
#             geo_json_ade4b0c32f80ac0a5f507561177049ed
#                 .addData(data)
#                 .addTo(choropleth_18d7dcbb32443d82bf510f49717b020f);
#         }
#             geo_json_ade4b0c32f80ac0a5f507561177049ed_add({&quot;bbox&quot;: [-9.237916, 38.680028, -9.086309, 38.796755], &quot;features&quot;: [{&quot;bbox&quot;: [-9.210058, 38.700416, -9.186106, 38.724765], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-9.193357, 38.700578], [-9.19364, 38.700425], [-9.193656, 38.700416], [-9.193935, 38.700706], [-9.194264, 38.701098], [-9.194303, 38.701087], [-9.194649, 38.700992], [-9.196239, 38.700553], [-9.196724, 38.701578], [-9.196876, 38.701869], [-9.19825, 38.701951], [-9.198411, 38.701967], [-9.198485, 38.701975], [-9.198654, 38.702035], [-9.199119, 38.702199], [-9.199581, 38.702352], [-9.199587, 38.702287], [-9.199762, 38.701128], [-9.199777, 38.70103], [-9.199804, 38.700856], [-9.199946, 38.700887], [-9.200437, 38.700993], [-9.200763, 38.701081], [-9.200837, 38.701106], [-9.200869, 38.701116], [-9.20098, 38.701153], [-9.201005, 38.701176], [-9.201085, 38.701247], [-9.201741, 38.701436], [-9.201814, 38.701457], [-9.201893, 38.701481], [-9.202518, 38.701667], [-9.202427, 38.701988], [-9.202438, 38.702097], [-9.202448, 38.702189], [-9.202428, 38.702432], [-9.202405, 38.702728], [-9.202391, 38.703324], [-9.202382, 38.703704], [-9.202352, 38.704239], [-9.202336, 38.704539], [-9.202327, 38.704697], [-9.202319, 38.704853], [-9.202289, 38.705388], [-9.202288, 38.705411], [-9.202267, 38.705738], [-9.202296, 38.705928], [-9.202301, 38.70595], [-9.20231

# %%
visualization_with_folium(means_summary, 'Mean Ent. home',
                          capitals_lat_lng['Lisbon'],
                          new_nbh_geo_file['Lisbon'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2a410ef45be68f0269cb470442e750d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2a410ef45be68f0269cb470442e750d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2a410ef45be68f0269cb470442e750d = L.map(
#                 &quot;map_f2a410ef45be68f0269cb470442e750d&quot;,
#                 {
#                     center: [38.736946, -9.142685],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_199232aaad5c08c944d35fe81c6a2e4b = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f2a410ef45be68f0269cb470442e750d);
#
#
#             var marker_81a02f542f8ea416fca4a51f9b850155 = L.marker(
#                 [38.736946, -9.142685],
#                 {}
#             ).addTo(map_f2a410ef45be68f0269cb470442e750d);
#
#
#             var icon_96581abaac08da71c2c4a521ea389bc3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_81a02f542f8ea416fca4a51f9b850155.setIcon(icon_96581abaac08da71c2c4a521ea389bc3);
#
#
#             var choropleth_61b4e4cb5b369a83ec549fb3900fa210 = L.featureGroup(
#                 {}
#             ).addTo(map_f2a410ef45be68f0269cb470442e750d);
#
#
#         function geo_json_1a0da60827aab91203949c329f6422f9_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;: case &quot;4&quot;: case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#91cf60&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;6&quot;: case &quot;12&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9ef8b&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1a9850&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d73027&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee08b&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.6, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_1a0da60827aab91203949c329f6422f9_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1a0da60827aab91203949c329f6422f9 = L.geoJson(null, {
#                 onEachFeature: geo_json_1a0da60827aab91203949c329f6422f9_onEachFeature,
#
#                 style: geo_json_1a0da60827aab91203949c329f6422f9_styler,
#         });
#
#         function geo_json_1a0da60827aab91203949c329f6422f9_add (data) {
#             geo_json_1a0da60827aab91203949c329f6422f9
#                 .addData(data)
#                 .addTo(choropleth_61b4e4cb5b369a83ec549fb3900fa210);
#         }
#             geo_json_1a0da60827aab91203949c329f6422f9_add({&quot;bbox&quot;: [-9.237916, 38.680028, -9.086309, 38.796755], &quot;features&quot;: [{&quot;bbox&quot;: [-9.210058, 38.700416, -9.186106, 38.724765], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-9.193357, 38.700578], [-9.19364, 38.700425], [-9.193656, 38.700416], [-9.193935, 38.700706], [-9.194264, 38.701098], [-9.194303, 38.701087], [-9.194649, 38.700992], [-9.196239, 38.700553], [-9.196724, 38.701578], [-9.196876, 38.701869], [-9.19825, 38.701951], [-9.198411, 38.701967], [-9.198485, 38.701975], [-9.198654, 38.702035], [-9.199119, 38.702199], [-9.199581, 38.702352], [-9.199587, 38.702287], [-9.199762, 38.701128], [-9.199777, 38.70103], [-9.199804, 38.700856], [-9.199946, 38.700887], [-9.200437, 38

# %% [markdown]
# # Store the mean values into a new file

# %% [markdown]
# I will store the mean values into a new csv and it will be used directly in streamlit

# %%
means_summary.to_csv("mean_values_per_neighbourhoods.csv")

# %% [markdown]
# # Store the new neighbourhoods geojson files

# %% [markdown]
# I will store the neighbourhoods with mean values into geojson files for each city.

# %%
new_nbh_geo_file['Amsterdam'].to_file("Amsterdam_neighbourhoods/new_neighbourhoods.geojson", driver="GeoJSON")
new_nbh_geo_file['Vienna'].to_file("Vienna_neighbourhoods/new_neighbourhoods.geojson", driver="GeoJSON")
new_nbh_geo_file['Rome'].to_file("Rome_neighbourhoods/new_neighbourhoods.geojson", driver="GeoJSON")
new_nbh_geo_file['Lisbon'].to_file("Lisbon_neighbourhoods/new_neighbourhoods.geojson", driver="GeoJSON")
new_nbh_geo_file['Paris'].to_file("Paris_neighbourhoods/new_neighbourhoods.geojson", driver="GeoJSON")
new_nbh_geo_file['London'].to_file("London_neighbourhoods/new_neighbourhoods.geojson", driver="GeoJSON")
